# %%
import pandas as pd

from initialize_shipping_time_df import get_article_production_duration_df
from domain.model.stock import Stock

# %%
all_production_time = get_article_production_duration_df()

all_products = all_production_time

all_products = all_products.drop(columns=["duration_producer", "duration_coating"])

all_products["amount"] = int(0)

all_products["min_amount"] = int(5)

all_products
# Out:
#          SKU             Beschichtung  producer  duration  production_line  \
# 0     9101UB            unbeschichtet         3        10                1
# 1     9101FZ            feuerverzinkt         3        25                1
# 2     9101DX                   DB 703         3        25                1
# 3     9101SF             Sonderfarben         3        25                1
# 4     9102UB            unbeschichtet         2        20                1
# ..       ...                      ...       ...       ...              ...
# 69   SZ21022            unbeschichtet         1        15                3
# 70  SZ2102SF              Sonderfarbe         1        30                3
# 71   SZ21031  pulverbeschichtet DB703         1        30                3
# 72   SZ21032            unbeschichtet         1        15                3
# 73  SZ2103SF              Sonderfarbe         1        30                3
#
#     amount  min_amount
# 0        0           5
# 1        0           5
# 2        0           5
# 3        0           5
# 4        0           5
# ..     ...         ...
# 69       0           5
# 70       0           5
# 71       0           5
# 72       0           5
# 73       0           5
#
# [244 rows x 7 columns]
